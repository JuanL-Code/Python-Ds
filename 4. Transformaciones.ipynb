# %%
import pandas as pd
df = pd.read_csv('base_datos_2008.csv.bz2')

# %%
df['HoursDelay'] = round(df['ArrDelay']/60, 3)

# %%
df['HoursDelay']
# Out:
# 0         -0.233
# 1          0.033
# 2          0.233
# 3         -0.100
# 4          0.567
#            ...
# 7009723    0.233
# 7009724   -0.033
# 7009725    0.000
# 7009726    0.150
# 7009727   -0.083
# Name: HoursDelay, Length: 7009728, dtype: float64

# %%
df = df.drop(['Diverted'], axis = 1)

# %%
dfATL = df[df.Origin == 'ATL']
dfHOU = df[df.Origin == 'HOU']

# %%
dfCIU = dfATL.append(dfHOU)
dfCIU
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 103149   2008      1          21          1   1207.0        1210   1346.0
# 103572   2008      1          12          6   1458.0        1500   1622.0
# 104019   2008      1          20          7   1403.0        1330   1625.0
# 104124   2008      1          26          6   1629.0        1630   1832.0
# 104485   2008      1           4          5   1336.0        1340   1501.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 7003419  2008     12           8          1   1053.0        1050   1354.0
# 7004690  2008     12           9          2   1105.0        1050   1411.0
# 7005947  2008     12          10          3   1313.0        1050   1634.0
# 7007233  2008     12          11          4   1047.0        1050   1355.0
# 7008545  2008     12          12          5   1114.0        1050   1406.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...
